# %%
from data import create_dataset
import webdataset as wds

# %%
ds = create_dataset(batch_size=4)
dl = wds.WebLoader(ds, num_workers=2, batch_size=None)

# %%
batch = next(iter(dl))
image = batch[0]
cls = batch[1]
print(image.shape)
print(cls)
# Out:
#   Cell In[4], line 3
#     class = batch[1]
#           ^
# SyntaxError: invalid syntax
